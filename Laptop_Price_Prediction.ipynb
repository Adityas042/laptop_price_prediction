# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Laptop Price Dataset

# %%
df=pd.read_csv("/content/laptop_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df=df.drop("Unnamed: 0",axis=1)

# %% [markdown]
# #Feature Engineering on Columns

# %%
df['Ram']=df['Ram'].str.replace("GB","").astype('int32')
df['Weight']=df['Weight'].str.replace("kg","").astype('float32')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# <ipython-input-13-51888cb550e6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['TouchScreen']=df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df.sample(10)
# Out:
#      Company     TypeName  Inches   ScreenResolution  \
# 476     Dell  Workstation    15.6  Full HD 1920x1080
# 177      MSI       Gaming    18.4  Full HD 1920x1080
# 98      Asus     Notebook    15.6  Full HD 1920x1080
# 906       HP      Netbook    12.5  Full HD 1920x1080
# 1138     MSI       Gaming    17.3  Full HD 1920x1080
# 227     Asus     Notebook    15.6  Full HD 1920x1080
# 717   Lenovo     Notebook    15.6           1366x768
# 910     Dell     Notebook    14.0  Full HD 1920x1080
# 1009      HP     Notebook    14.0           1366x768
# 783   Lenovo     Notebook    15.6           1366x768
#
#                                        Cpu  Ram                Memory  \
# 476            Intel Core i7 7700HQ 2.8GHz    8             256GB SSD
# 177            Intel Core i7 6920HQ 2.9GHz   32  512GB SSD +  1TB HDD
# 98              Intel Core i3 7100U 2.4GHz    6             256GB SSD
# 906             Intel Core i7 7500U 2.7GHz    8             512GB SSD
# ...

# %%
df['IPS_Panel']=df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df.sample(10)
# Out:
#      Company   TypeName  Inches             ScreenResolution  \
# 1236      HP  Ultrabook    14.0                    2560x1440
# 824   Lenovo  Ultrabook    14.0  IPS Panel Full HD 1920x1080
# 773     Dell     Gaming    15.6            Full HD 1920x1080
# 620       HP   Notebook    14.0                     1366x768
# 577   Lenovo     Gaming    17.3  IPS Panel Full HD 1920x1080
# 98      Asus   Notebook    15.6            Full HD 1920x1080
# 371     Acer   Notebook    15.6                     1366x768
# 251     Asus     Gaming    17.3            Full HD 1920x1080
# 485   Lenovo   Notebook    14.0  IPS Panel Full HD 1920x1080
# 859   Lenovo   Notebook    15.6            Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 1236   Intel Core i7 6500U 2.5GHz    8             256GB SSD
# 824    Intel Core i5 7200U 2.5GHz    8   256GB Flash Storage
# 773   Intel Core i7 7700HQ 2.8GHz    8               1TB HDD
# ...

# %%
import re

pattern = r'\d+x\d+'
df['X_res']=df['ScreenResolution'].apply(lambda x:re.findall(pattern,x)[0].split('x')[0])
df['Y_res']=df['ScreenResolution'].apply(lambda x:re.findall(pattern,x)[0].split('x')[1])

# %%
df['X_res']=df['X_res'].astype('int32')
df['Y_res']=df['Y_res'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS_Panel         1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df=df.drop(['ScreenResolution'],axis=1)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu  Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz    8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz    8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  IPS_Panel  X_res  Y_res
# 0   71378.6832            0          1   2560   1600
# 1   47895.5232            0          0   1440    900
# ...

# %%
df.corr()['Price']
# Out:
# <ipython-input-24-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# IPS_Panel      0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df['PPI']=((df['X_res']**2) +(df['Y_res']**2))**0.5/df['Inches']

# %%
df.corr()['Price']
# Out:
# <ipython-input-26-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# IPS_Panel      0.252208
# X_res          0.556529
# Y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
df=df.drop(['Inches','X_res','Y_res'],axis=1)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS_Panel         PPI
# 0          1  226.983005
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS_Panel         PPI       Cpu name
# ...

# %%
def getdata(text):
    if text=="Intel Core i3" or text=="Intel Core i5" or text=="Intel Core i7" :
       return text
    else:
      if "Intel" in text:
         return "other Intel processor"
      else:
         return "AMD processor"

# %%
df['Cpu brand']=df['Cpu name'].apply(lambda x:getdata(x))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS_Panel         PPI       Cpu name      Cpu brand
# ...

# %%
df=df.drop(['Cpu','Cpu name'],axis=1)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS_Panel         PPI  \
# 0  macOS    1.37   71378.6832            0          1  226.983005
# 1  macOS    1.34   47895.5232            0          0  127.677940
# 2  No OS    1.86   30636.0000            0          0  141.211998
# 3  macOS    1.83  135195.3360            0          1  220.534624
# 4  macOS    1.37   96095.8080            0          1  226.983005
#
#        Cpu brand
# 0  Intel Core i5
# 1  Intel Core i5
# 2  Intel Core i5
# 3  Intel Core i7
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['SSD']=df['Memory'].apply(lambda x: re.search(r'\d+?GB\sSSD|\d+?TB\sSSD',x).group(0) if 'SSD' in x else 0)
df['HDD']=df['Memory'].apply(lambda x: re.search(r'\d+?GB\sHDD|\d+?TB\sHDD',x).group(0) if 'HDD' in x else 0)
df['Flash Storage']=df['Memory'].apply(lambda x: re.search(r'\d+?GB|\d+?TB',x).group(0) if 'Flash Storage' in x else 0)
df['Hybrid']=df['Memory'].apply(lambda x: re.search(r'\d+?GB\sHybrid|\d+\.\d?TB\sHybrid',x).group(0) if 'Hybrid' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS_Panel         PPI  \
# 0  macOS    1.37   71378.6832            0          1  226.983005
# 1  macOS    1.34   47895.5232            0          0  127.677940
# 2  No OS    1.86   30636.0000            0          0  141.211998
# 3  macOS    1.83  135195.3360            0          1  220.534624
# 4  macOS    1.37   96095.8080            0          1  226.983005
#
#        Cpu brand        SSD HDD Flash Storage Hybrid
# ...

# %%
df['SSD']=df['SSD'].str.replace('SSD','').str.replace('GB','').str.replace('1TB','1024')
df['HDD']=df['HDD'].str.replace('HDD','').str.replace('GB','').str.replace('1TB','1024').str.replace('2TB','2048')
df['Flash Storage']=df['Flash Storage'].str.replace('GB','').str.replace('1TB','1024')
df['Hybrid']=df['Hybrid'].str.replace('Hybrid','').str.replace('GB','').str.replace('1.0TB','1024')
# Out:
# <ipython-input-41-5e96f7f7163c>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Hybrid']=df['Hybrid'].str.replace('Hybrid','').str.replace('GB','').str.replace('1.0TB','1024')

# %%
df.head(10)
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
# 5    Acer   Notebook    4            500GB HDD                 AMD Radeon R5
# 6   Apple  Ultrabook   16  256GB Flash Storage       Intel Iris Pro Graphics
# 7   Apple  Ultrabook    8  256GB Flash Storage        Intel HD Graphics 6000
# 8    Asus  Ultrabook   16            512GB SSD          Nvidia GeForce MX150
# 9    Acer  Ultrabook    8            256GB SSD        Intel UHD Graphics 620
#
#         OpSys  Weight        Price  TouchScreen  IPS_Panel         PPI  \
# ...

# %%
df=df.replace(np.nan,'0')

# %%
df['SSD']=df['SSD'].astype('int32')

df['Flash Storage']=df['Flash Storage'].astype('int32')
df['Hybrid']=df['Hybrid'].astype('int32')

df['HDD']=df['HDD'].str.replace('0TB','0')
df['HDD']=df['HDD'].astype('int32')

# %%
df.sample(10)
# Out:
#       Company   TypeName  Ram                Memory  \
# 892   Samsung  Ultrabook    8             256GB SSD
# 491   Toshiba  Ultrabook   32             512GB SSD
# 356    Lenovo   Notebook    4               1TB HDD
# 69       Asus     Gaming   12               1TB HDD
# 110      Asus  Ultrabook   16  256GB SSD +  1TB HDD
# 1197     Asus     Gaming   16  512GB SSD +  1TB HDD
# 549    Lenovo   Notebook    8             512GB SSD
# 820    Lenovo   Notebook    4             500GB HDD
# 317    Lenovo   Notebook    4    16GB Flash Storage
# 24         HP  Ultrabook    8             256GB SSD
#
#                              Gpu       OpSys  Weight        Price  \
# 892        Intel HD Graphics 620  Windows 10    1.17   90522.7200
# 491        Intel HD Graphics 620  Windows 10    1.05  149130.7200
# 356        Intel HD Graphics 500       No OS    2.20   17155.6272
# 69    Nvidia GeForce GTX 1050 Ti       Linux    3.00   50562.7200
# ...

# %%
df=df.drop(['Memory'],axis=1)

# %%
df.corr()['Price']
# Out:
# <ipython-input-47-9447c1bc3d29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# IPS_Panel        0.252208
# PPI              0.473487
# SSD              0.675986
# HDD             -0.093112
# Flash Storage   -0.040511
# Hybrid           0.008011
# Name: Price, dtype: float64

# %%
df=df.drop(['Flash Storage','Hybrid'],axis=1)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  IPS_Panel         PPI      Cpu brand  SSD  HDD
# 0   71378.6832            0          1  226.983005  Intel Core i5  128    0
# 1   47895.5232            0          0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0          0  141.211998  Intel Core i5  256    0
# 3  135195.3360            0          1  220.534624  Intel Core i7  512    0
# 4   96095.8080            0          1  226.983005  Intel Core i5  256    0

# %%
df['Gpu Brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu Brand, dtype: int64

# %%
df=df[df['Gpu Brand']!='ARM']

# %%
df['Gpu Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu Brand, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  IPS_Panel         PPI      Cpu brand  SSD  HDD  \
# 0   71378.6832            0          1  226.983005  Intel Core i5  128    0
# 1   47895.5232            0          0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0          0  141.211998  Intel Core i5  256    0
# 3  135195.3360            0          1  220.534624  Intel Core i7  512    0
# 4   96095.8080            0          1  226.983005  Intel Core i5  256    0
#
#   Gpu Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def os_cat(text):
    if text=='Windows 10' or text=='Windows 10 S' or text=='Windows 7':
       return 'Windows'
    elif text=='mac OS' or text=='Mac OS X':
         return 'Mac'
    else:
        return 'Others/No OS/Linux/'

# %%
df['OpSys'].apply(os_cat)
# Out:
# 0       Others/No OS/Linux/
# 1       Others/No OS/Linux/
# 2       Others/No OS/Linux/
# 3       Others/No OS/Linux/
# 4       Others/No OS/Linux/
#                ...
# 1298                Windows
# 1299                Windows
# 1300                Windows
# 1301                Windows
# 1302                Windows
# Name: OpSys, Length: 1302, dtype: object

# %%
df['OS']=df['OpSys'].apply(os_cat)

# %%
df=df.drop(['OpSys'],axis=1)

# %%
df=df.drop(['Gpu'],axis=1)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  TouchScreen  IPS_Panel  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0          1
# 1   Apple  Ultrabook    8    1.34   47895.5232            0          0
# 2      HP   Notebook    8    1.86   30636.0000            0          0
# 3   Apple  Ultrabook   16    1.83  135195.3360            0          1
# 4   Apple  Ultrabook    8    1.37   96095.8080            0          1
#
#           PPI      Cpu brand  SSD  HDD Gpu Brand                   OS
# 0  226.983005  Intel Core i5  128    0     Intel  Others/No OS/Linux/
# 1  127.677940  Intel Core i5    0    0     Intel  Others/No OS/Linux/
# 2  141.211998  Intel Core i5  256    0     Intel  Others/No OS/Linux/
# 3  220.534624  Intel Core i7  512    0       AMD  Others/No OS/Linux/
# 4  226.983005  Intel Core i5  256    0     Intel  Others/No OS/Linux/

# %%
sns.displot(df['Weight'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-64-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.distplot(df['Price'])
# Out:
# <ipython-input-65-87e11caeb2c4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <ipython-input-66-c1a82a4801f0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X=df.drop(['Price'],axis=1)
Y=np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  TouchScreen  IPS_Panel  \
# 0      Apple           Ultrabook    8    1.37            0          1
# 1      Apple           Ultrabook    8    1.34            0          0
# 2         HP            Notebook    8    1.86            0          0
# 3      Apple           Ultrabook   16    1.83            0          1
# 4      Apple           Ultrabook    8    1.37            0          1
# ...      ...                 ...  ...     ...          ...        ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1          1
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1          1
# 1300  Lenovo            Notebook    2    1.50            0          0
# 1301      HP            Notebook    6    2.19            0          0
# 1302    Asus            Notebook    4    2.20            0          0
#
#              PPI              Cpu brand  SSD   HDD Gpu Brand  \
# 0     226.983005          Intel Core i5  128     0     Intel
# ...

# %%
Y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  TouchScreen  IPS_Panel  \
# 183   Toshiba            Notebook    8    2.00            0          0
# 1141      MSI              Gaming    8    2.40            0          0
# 1049     Asus             Netbook    4    1.20            0          0
# 1020     Dell  2 in 1 Convertible    4    2.08            1          1
# 878      Dell            Notebook    4    2.18            0          0
# ...       ...                 ...  ...     ...          ...        ...
# 466      Acer            Notebook    4    2.20            0          0
# 299      Asus           Ultrabook   16    1.63            0          0
# 493      Acer            Notebook    8    2.20            0          0
# 527    Lenovo            Notebook    8    2.20            0          0
# 1193    Apple           Ultrabook    8    0.92            0          1
#
#              PPI              Cpu brand  SSD   HDD Gpu Brand  \
# ...

# %%
Y_train
# Out:
# 183     10.651384
# 1141    11.016798
# 1049     9.638174
# 1020    10.655148
# 878     10.791749
#           ...
# 466     10.126164
# 299     11.267217
# 493     10.336864
# 527     10.104611
# 1193    11.034319
# Name: Price, Length: 1106, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

# %% [markdown]
# #Linear Regression

# %%
from sklearn.linear_model import LinearRegression


transformers = [
    ('tnf1', OneHotEncoder(sparse=False, drop='first'), [0, 1, 7, 10, 11])
]


step1 = ColumnTransformer(transformers=transformers, remainder='passthrough')


step2 = LinearRegression()


pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])


pipe.fit(X_train, Y_train)


Y_pred = pipe.predict(X_test)


print('R2_score=', r2_score(Y_test, Y_pred))
print('Mean Absolute error=', mean_absolute_error(Y_test, Y_pred))
# Out:
# R2_score= 0.8080688541232683
# Mean Absolute error= 0.20902080904244388
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Random Forest Regression Model

# %%
from sklearn.ensemble import RandomForestRegressor


transformers = [
    ('tnf1', OneHotEncoder(sparse=False, drop='first'), [0, 1, 7, 10, 11])
]


step1 = ColumnTransformer(transformers=transformers, remainder='passthrough')


step2 = RandomForestRegressor()


pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])


pipe.fit(X_train, Y_train)


Y_pred = pipe.predict(X_test)


print('R2_score=', r2_score(Y_test, Y_pred))
print('Mean Absolute error=', mean_absolute_error(Y_test, Y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2_score= 0.8877175432011087
# Mean Absolute error= 0.15426073638078341
